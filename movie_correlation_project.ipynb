# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] =(12,8)


df = pd.read_csv (r'C:\Users\amash\OneDrive\Desktop\movies.csv')
print (df)
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
sns.regplot(x="gross", y="budget", data=df)
# Out:
# <AxesSubplot:xlabel='gross', ylabel='budget'>

# %%
 #plot budget vs gross using seaborn 
sns.regplot(x='budget', y='gross', data=df, scatter_kws ={"color":"red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
df.corr(method='pearson')
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating   -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre     0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year      0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
# score     0.017097 -0.001314  0.027965  0.097995  0.042788  1.000000
# votes     0.013088  0.033225 -0.145307  0.222945  0.016097  0.409182
# director  0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.009559
# writer    0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.019416
# star      0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.001609
# country  -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133348
# budget    0.023970 -0.176002 -0.356564  0.329321  0.014683  0.076254
# gross     0.005533 -0.107339 -0.235650  0.257486  0.001659  0.186258
# ...

# %%
correlation_matrx=df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot =True)
plt.show()

# %%
df.corr(method ='kendall')
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.009373  0.011615  0.007957 -0.007514  0.007769
# rating   -0.009373  1.000000  0.100890 -0.000516  0.023896  0.019863
# genre     0.011615  0.100890  1.000000 -0.059866  0.021527  0.049721
# year      0.007957 -0.000516 -0.059866  1.000000  0.000399  0.067652
# released -0.007514  0.023896  0.021527  0.000399  1.000000  0.027612
# score     0.007769  0.019863  0.049721  0.067652  0.027612  1.000000
# votes     0.005842  0.017004 -0.149969  0.331465 -0.008681  0.300115
# director  0.005961  0.007735 -0.012338 -0.013311 -0.000762  0.010082
# writer    0.006196  0.001079  0.002779 -0.005800 -0.001510  0.013060
# star      0.004366  0.013431 -0.003664 -0.018181  0.010395  0.000163
# country  -0.005985  0.022408 -0.056763 -0.068822 -0.020635 -0.172293
# budget    0.014819 -0.198859 -0.278966  0.224120 -0.003801 -0.000566
# gross    -0.000495 -0.134830 -0.210893  0.200618 -0.028470  0.086046
# ...

# %%
df.corr(method ='spearman')
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.012197  0.015940  0.011978 -0.011298  0.011505
# rating   -0.012197  1.000000  0.123670 -0.000120  0.031884  0.024234
# genre     0.015940  0.123670  1.000000 -0.081261  0.029685  0.067659
# year      0.011978 -0.000120 -0.081261  1.000000 -0.000334  0.099045
# released -0.011298  0.031884  0.029685 -0.000334  1.000000  0.041079
# score     0.011505  0.024234  0.067659  0.099045  0.041079  1.000000
# votes     0.008739  0.022363 -0.204214  0.469829 -0.014314  0.428138
# director  0.008912  0.010232 -0.016710 -0.019843 -0.001206  0.014691
# writer    0.009201  0.001379  0.003902 -0.008666 -0.002330  0.019175
# star      0.006639  0.017564 -0.004860 -0.026876  0.015694  0.000372
# country  -0.007715  0.025221 -0.067968 -0.088509 -0.026772 -0.218330
# budget    0.022180 -0.254885 -0.376346  0.317336 -0.006394 -0.001403
# gross    -0.000634 -0.173251 -0.288896  0.293084 -0.045193  0.126116
# ...

# %%
correlation_matrix =df.corr(method='spearman')
sns.heatmap(correlation_matrix, annot =True)
plt.show()

# %%
correlation_matrix =df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot =True)
plt.show()

# %%
df.corr( method ='kendall')
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.009373  0.011615  0.007957 -0.007514  0.007769
# rating   -0.009373  1.000000  0.100890 -0.000516  0.023896  0.019863
# genre     0.011615  0.100890  1.000000 -0.059866  0.021527  0.049721
# year      0.007957 -0.000516 -0.059866  1.000000  0.000399  0.067652
# released -0.007514  0.023896  0.021527  0.000399  1.000000  0.027612
# score     0.007769  0.019863  0.049721  0.067652  0.027612  1.000000
# votes     0.005842  0.017004 -0.149969  0.331465 -0.008681  0.300115
# director  0.005961  0.007735 -0.012338 -0.013311 -0.000762  0.010082
# writer    0.006196  0.001079  0.002779 -0.005800 -0.001510  0.013060
# star      0.004366  0.013431 -0.003664 -0.018181  0.010395  0.000163
# country  -0.005985  0.022408 -0.056763 -0.068822 -0.020635 -0.172293
# budget    0.014819 -0.198859 -0.278966  0.224120 -0.003801 -0.000566
# gross    -0.000495 -0.134830 -0.210893  0.200618 -0.028470  0.086046
# ...

# %%
correlation_matrix =df.corr(method='kendall')
sns.heatmap(correlation_matrix, annot =True)
plt.show()

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot =True)
plt.title("Correlation matrix for Numeric Features")
plt.xlabel("Movie features")
plt.ylabel("Movie features")
plt.show()

# %%
#using facorize - this assigns a random numeric value for each unique categorical value
df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000  0.143938  0.036367  0.965761  0.959015 -0.046733
# rating    0.143938  1.000000 -0.086723  0.156713  0.146606  0.012595
# genre     0.036367 -0.086723  1.000000  0.037184  0.035940 -0.002437
# year      0.965761  0.156713  0.037184  1.000000  0.993190 -0.044981
# released  0.959015  0.146606  0.035940  0.993190  1.000000 -0.045761
# score    -0.046733  0.012595 -0.002437 -0.044981 -0.045761  1.000000
# votes     0.287776  0.099972  0.023285  0.312401  0.299905 -0.009749
# director  0.745905  0.085520  0.047288  0.770497  0.770876 -0.022687
# writer    0.805211  0.103623  0.033688  0.824770  0.819617 -0.034685
# star      0.731565  0.093116  0.038649  0.756400  0.754468 -0.009896
# country   0.142828  0.000494 -0.015795  0.140216  0.148468  0.023097
# budget    0.277488  0.193353  0.073008  0.300621  0.285691 -0.012642
# gross     0.947324  0.158582  0.038616  0.980873  0.976423 -0.047041
# ...

# %%
correlation_matrix = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
sns.heatmap(correlation_matrix, annot = True)
plt.title("Correlation matrix for Movies")
plt.xlabel("Movie features")
plt.ylabel("Movie features")
plt.show()

# %%
correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()
corr_pairs=correlation_mat.unstack()
print(corr_pairs)
# Out:
# name     name        1.000000
#          rating      0.143938
#          genre       0.036367
#          year        0.965761
#          released    0.959015
#                        ...
# runtime  country     0.124154
#          budget      0.112097
#          gross       0.042978
#          company     0.005137
#          runtime     1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs=corr_pairs.sort_values(kind ="quicksort")
print(sorted_pairs)
# Out:
# budget   genre     -0.356564
# genre    budget    -0.356564
#          gross     -0.235650
# gross    genre     -0.235650
# rating   budget    -0.176002
#                       ...
# year     year       1.000000
# genre    genre      1.000000
# rating   rating     1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# Length: 225, dtype: float64

# %%
#find data with a high correlation (>0.5)
strong_pairs=sorted_pairs[abs(sorted_pairs) > 0.5]
print(strong_pairs)
# Out:
# star      company    0.527116
# company   star       0.527116
#           writer     0.546151
# writer    company    0.546151
# director  company    0.552258
#                        ...
# year      year       1.000000
# genre     genre      1.000000
# rating    rating     1.000000
# company   company    1.000000
# runtime   runtime    1.000000
# Length: 71, dtype: float64

# %%
#look up top 15 company gross revenue
CompanyGrossSum = df.groupby('company')[["gross"]].sum()
CompanyGrossSumSorted = CompanyGrossSum.sort_values('gross', ascending =False)[:15]
CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64')
CompanyGrossSumSorted
# Out:
# company
# Warner Bros.                 56491421806
# Universal Pictures           52514188890
# Columbia Pictures            43008941346
# Paramount Pictures           40493607415
# Twentieth Century Fox        40257053857
# Walt Disney Pictures         36327887792
# New Line Cinema              19883797684
# Marvel Studios               15065592411
# DreamWorks Animation         11873612858
# Touchstone Pictures          11795832638
# Dreamworks Pictures          11635441081
# Metro-Goldwyn-Mayer (MGM)     9230230105
# Summit Entertainment          8373718838
# Pixar Animation Studios       7886344526
# Fox 2000 Pictures             7443502667
# Name: gross, dtype: int64

# %%
df['Year'] = df['released'].astype(str).str[:4]
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime  Year
# 0  1047       54  19000000.0   46998772.0     2319    146.0  1705
# 1   327       55   4500000.0   58853106.0      731    104.0  1492
# 2  1745       55  18000000.0  538375067.0     1540    124.0  1771
# 3  2246       55   3500000.0   83453539.0     1812     88.0  1492
# 4   410       55   6000000.0   39846344.0     1777     98.0  1543

# %%
CompanyGrossSum = df.groupby(['company', 'year'])[["gross"]].sum()
CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross', 'company', 'year'], ascending =False)[:15]
CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64')
CompanyGrossSumSorted
# Out:
# company                year
# Walt Disney Pictures   2019    5773131804
# Marvel Studios         2018    4018631866
# Universal Pictures     2015    3834354888
# Twentieth Century Fox  2009    3793491246
# Walt Disney Pictures   2017    3789382071
# Paramount Pictures     2011    3565705182
# Warner Bros.           2010    3300479986
#                        2011    3223799224
# Walt Disney Pictures   2010    3104474158
# Paramount Pictures     2014    3071298586
# Columbia Pictures      2006    2934631933
#                        2019    2932757449
# Marvel Studios         2019    2797501328
# Warner Bros.           2018    2774168962
# Columbia Pictures      2011    2738363306
# Name: gross, dtype: int64

# %%
CompanyGrossSum = df.groupby('company')[["gross"]].sum()
CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company'], ascending =False)[:15]
CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64')
CompanyGrossSumSorted
# Out:
# company
# 2319    56491421806
# 2281    52514188890
# 731     43008941346
# 1812    40493607415
# 2253    40257053857
# 2316    36327887792
# 1713    19883797684
# 1606    15065592411
# 887     11873612858
# 2232    11795832638
# 889     11635441081
# 1637     9230230105
# 2147     8373718838
# 1856     7886344526
# 1109     7443502667
# Name: gross, dtype: int64

# %%
plt.scatter(x=df['budget'],y=df['gross'], alpha=0.5)
plt.title('Budget vs Gross Earning')
plt.xlabel('Gross Earning')
plt.ylabel('Budget for Film')
plt.show()

# %%
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime  Year
# 0  1047       54  19000000.0   46998772.0     2319    146.0  1705
# 1   327       55   4500000.0   58853106.0      731    104.0  1492
# 2  1745       55  18000000.0  538375067.0     1540    124.0  1771
# 3  2246       55   3500000.0   83453539.0     1812     88.0  1492
# 4   410       55   6000000.0   39846344.0     1777     98.0  1543

# %%
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype=='object'):
        df_numerized[col_name]=df_numerized[col_name].astype('category')
        df_numerized[col_name]=df_numerized[col_name].cat.codes
df_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime  Year
# 0  1047       54  19000000.0   46998772.0     2319    146.0   787
# 1   327       55   4500000.0   58853106.0      731    104.0   550
# 2  1745       55  18000000.0  538375067.0     1540    124.0   860
# 3  2246       55   3500000.0   83453539.0     1812     88.0   550
# 4   410       55   6000000.0   39846344.0     1777     98.0   607

# %%
df_numerized.corr(method='pearson')
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating   -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre     0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year      0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
# score     0.017097 -0.001314  0.027965  0.097995  0.042788  1.000000
# votes     0.013088  0.033225 -0.145307  0.222945  0.016097  0.409182
# director  0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.009559
# writer    0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.019416
# star      0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.001609
# country  -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133348
# budget    0.023970 -0.176002 -0.356564  0.329321  0.014683  0.076254
# gross     0.005533 -0.107339 -0.235650  0.257486  0.001659  0.186258
# ...

# %%
df.groupby(['company', 'year'])[["gross"]].sum()

# %%
correlation_matrix = df_numerized.corr(method='pearson')
sns.heatmap(correlation_matrix, annot = True)
plt.title("Correlation matrix for Movies")
plt.xlabel("Movie features")
plt.ylabel("Movie features")
plt.show()

# %%
for col_name in df.columns:
    if(df[col_name].dtype =='object'):
        df[col_name]=df[col_name].astype('category')
        df[col_name]=df[col_name].cat.codes

# %%
sns.swarmplot(x="rating", y="gross", data=df).head()
# Out:
# C:\Users\amash\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 53.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\amash\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 48.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\amash\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 60.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\amash\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 80.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.stripplot(x="rating", y="gross", data=df)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='gross'>

# %%
df.dtypes==('object')
# Out:
# name        False
# rating      False
# genre       False
# year        False
# released    False
# score       False
# votes       False
# director    False
# writer      False
# star        False
# country     False
# budget      False
# gross       False
# company     False
# runtime     False
# dtype: bool

# %%
print(df).head()

# %%
#find missing data within the dataset
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{}-{}%'.format(col,round(pct_missing*100)))
# Out:
# name-0%
# rating-0%
# genre-0%
# year-0%
# released-0%
# score-0%
# votes-0%
# director-0%
# writer-0%
# star-0%
# country-0%
# budget-28%
# gross-2%
# company-0%
# runtime-0%

# %%
#Column data types 
print(df.dtypes)
# Out:
# name          int16
# rating         int8
# genre          int8
# year          int64
# released      int16
# score       float64
# votes       float64
# director      int16
# writer        int16
# star          int16
# country        int8
# budget      float64
# gross       float64
# company       int16
# runtime     float64
# dtype: object

# %%
#Are there any outliers?
df.boxplot(column=['gross'])
# Out:
# <AxesSubplot:>

# %%
print(df).head()

# %%
display(df.describe())

# %%
display(df.head())

# %%
display(df.dtypes.value_counts())

# %%
df.dtypes=='object'
# Out:
# name        False
# rating      False
# genre       False
# year        False
# released    False
# score       False
# votes       False
# director    False
# writer      False
# star        False
# country     False
# budget      False
# gross       False
# company     False
# runtime     False
# dtype: bool

# %%
#Seperate numerical and categorical variables 
num_vars= df.columns[df.dtypes != 'object']
cat_vars = df.columns[df.dtypes == 'object']
print(num_vars) 
print(cat_vars)
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')
# Index([], dtype='object')

# %%
df

# %%
#Find missing numerical values that do not have a data type
df[num_vars]

# %%
df[num_vars].isnull()

# %%
#Find missing values in each column
df[num_vars].isnull().sum()
# Out:
# name           0
# rating         0
# genre          0
# year           0
# released       0
# score          3
# votes          3
# director       0
# writer         0
# star           0
# country        0
# budget      2171
# gross        189
# company        0
# runtime        4
# dtype: int64

# %%
df
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1     5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2     5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3      286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4     1027       6      4  1980      1543    7.3   108000.0      1054     521
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705      -1      6  2020      2964    3.1       18.0      1500    2289
# 7664  1678      -1      4  2020      1107    4.7       36.0       774    2614
# 7665  4717      -1      6  2020       193    5.7       29.0      2061    2683
# 7666  2843      -1      6  2020      2817    NaN        NaN      1184    1824
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
#
# ...

# %%
#find column with the highest missing values 
df[num_vars].isnull().sum().sort_values(ascending=False)
# Out:
# budget      2171
# gross        189
# runtime        4
# score          3
# votes          3
# name           0
# rating         0
# genre          0
# year           0
# released       0
# director       0
# writer         0
# star           0
# country        0
# company        0
# dtype: int64

# %%
df

# %%
#find the percentage of missing values 
df[num_vars].isnull().sum().sort_values(ascending=False)/len(df)
# Out:
# budget      0.283125
# gross       0.024648
# runtime     0.000522
# score       0.000391
# votes       0.000391
# name        0.000000
# rating      0.000000
# genre       0.000000
# year        0.000000
# released    0.000000
# director    0.000000
# writer      0.000000
# star        0.000000
# country     0.000000
# company     0.000000
# dtype: float64

# %%
df.drop_duplicates()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1     5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2     5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3      286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4     1027       6      4  1980      1543    7.3   108000.0      1054     521
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705      -1      6  2020      2964    3.1       18.0      1500    2289
# 7664  1678      -1      4  2020      1107    4.7       36.0       774    2614
# 7665  4717      -1      6  2020       193    5.7       29.0      2061    2683
# 7666  2843      -1      6  2020      2817    NaN        NaN      1184    1824
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
#
# ...

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       5      0  2009       696    7.8  1100000.0      1155    1778
# 7445   535       5      0  2019       183    8.4   903000.0       162     743
# 3045  6896       5      6  1997       704    7.8  1100000.0      1155    1778
# 6663  5144       5      0  2015       698    7.8   876000.0      1125    2550
# 7244   536       5      0  2018       192    8.4   897000.0       162     743
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705      -1      6  2020      2964    3.1       18.0      1500    2289
# 7664  1678      -1      4  2020      1107    4.7       36.0       774    2614
# 7665  4717      -1      6  2020       193    5.7       29.0      2061    2683
# 7666  2843      -1      6  2020      2817    NaN        NaN      1184    1824
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
#
# ...

# %%
sns.regplot(x="gross", y="budget", data=df)
# Out:
# <AxesSubplot:xlabel='gross', ylabel='budget'>

# %%
print(df)
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1     5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2     5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3      286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4     1027       6      4  1980      1543    7.3   108000.0      1054     521
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705      -1      6  2020      2964    3.1       18.0      1500    2289
# 7664  1678      -1      4  2020      1107    4.7       36.0       774    2614
# 7665  4717      -1      6  2020       193    5.7       29.0      2061    2683
# 7666  2843      -1      6  2020      2817    NaN        NaN      1184    1824
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
#
# ...

# %%
df
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1     5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2     5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3      286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4     1027       6      4  1980      1543    7.3   108000.0      1054     521
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705      -1      6  2020      2964    3.1       18.0      1500    2289
# 7664  1678      -1      4  2020      1107    4.7       36.0       774    2614
# 7665  4717      -1      6  2020       193    5.7       29.0      2061    2683
# 7666  2843      -1      6  2020      2817    NaN        NaN      1184    1824
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
#
# ...

# %%
#update company data type from string to numeric
df_numerized=df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype =='object'):
       df_numerized[col_name]=df_numerized[col_name].astype('category')
       df_numerized[col_name] = df_numerized[col_name].cat.codes
df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1     5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2     5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3      286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4     1027       6      4  1980      1543    7.3   108000.0      1054     521
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705      -1      6  2020      2964    3.1       18.0      1500    2289
# 7664  1678      -1      4  2020      1107    4.7       36.0       774    2614
# 7665  4717      -1      6  2020       193    5.7       29.0      2061    2683
# 7666  2843      -1      6  2020      2817    NaN        NaN      1184    1824
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
#
# ...

# %%
df_numerized.corr().head()

# %%
# Show fields and related attributes
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# name     name        1.000000
#          rating     -0.008069
#          genre       0.016355
#          year        0.011453
#          released   -0.011311
#                        ...
# runtime  country    -0.078412
#          budget      0.320447
#          gross       0.245216
#          company     0.034402
#          runtime     1.000000
# Length: 225, dtype: float64
