# %%
import pandas as pd

# %%
# columns& rows with ... need more detial info
tree_census =pd.read_csv(r'C:/Users/amash/TreeCensus.csv')
tree_census
# Out:
#         tree_id  block_id created_at  tree_dbh  stump_diam curb_loc status  \
# 0        180683    348711  8/27/2015         3           0   OnCurb  Alive
# 1        200540    315986   9/3/2015        21           0   OnCurb  Alive
# 2        204026    218365   9/5/2015         3           0   OnCurb  Alive
# 3        204337    217969   9/5/2015        10           0   OnCurb  Alive
# 4        189565    223043  8/30/2015        21           0   OnCurb  Alive
# ...         ...       ...        ...       ...         ...      ...    ...
# 683783   155433    217978  8/18/2015        25           0   OnCurb  Alive
# 683784   183795    348185  8/29/2015         7           0   OnCurb  Alive
# 683785   166161    401670  8/22/2015        12           0   OnCurb  Alive
# 683786   184028    504204  8/29/2015         9           0   OnCurb  Alive
# 683787   200607    306527   9/3/2015        23           0   OnCurb  Alive
#
# ...

# %%
tree_census_subset = tree_census[['tree_id', 'tree_dbh', 'stump_diam',
'curb_loc','status','health','spc_latin','steward','sidewalk','problems', 'root_stone',
'root_grate','root_other','root_other','trunk_wire','trnk_light','trnk_other',
'brch_light', 'brch_shoe', 'brch_other']]

tree_census_subset
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# ...

# %%
tree_census_subset['health'].value_counts()

# %%
#find row and column specific values by status
mask =((tree_census_subset['status']=='Stump') | (tree_census_subset['status'] == 'Dead'))
mask
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 683783    False
# 683784    False
# 683785    False
# 683786    False
# 683787    False
# Name: status, Length: 683788, dtype: bool

# %%
#find health column with NAN values and set a default value to Not Applicable 
tree_census_subset.loc[mask, 'health'] = tree_census_subset.loc[mask, 'health'].fillna('Not Applicable')

# %%
tree_census_subset[tree_census_subset['status']=='Stump']
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status          health  \
# 37       211205         0          16   OnCurb  Stump  Not Applicable
# 239      203597         0          15   OnCurb  Stump  Not Applicable
# 641      179766         0          30   OnCurb  Stump  Not Applicable
# 644      180619         0          10   OnCurb  Stump  Not Applicable
# 646      208828         0          15   OnCurb  Stump  Not Applicable
# ...         ...       ...         ...      ...    ...             ...
# 683348   152836         0          13   OnCurb  Stump  Not Applicable
# 683686   191219         0          25   OnCurb  Stump  Not Applicable
# 683695   170888         0           5   OnCurb  Stump  Not Applicable
# 683697   177922         0          17   OnCurb  Stump  Not Applicable
# 683699   172660         0           4   OnCurb  Stump  Not Applicable
#
#        spc_latin steward sidewalk problems root_stone root_grate root_other  \
# ...

# %%
#Set a default value of Not Applicable to all columns with NAN values 
#Mask variable contains rows and columns status "Stump" and "Dead" with NAN values
tree_census_subset.loc[mask] = tree_census_subset.loc[mask].fillna('Not Applicable')

# %%
tree_census_subset[tree_census_subset['status']=='Stump']
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status          health  \
# 37       211205         0          16   OnCurb  Stump  Not Applicable
# 239      203597         0          15   OnCurb  Stump  Not Applicable
# 641      179766         0          30   OnCurb  Stump  Not Applicable
# 644      180619         0          10   OnCurb  Stump  Not Applicable
# 646      208828         0          15   OnCurb  Stump  Not Applicable
# ...         ...       ...         ...      ...    ...             ...
# 683348   152836         0          13   OnCurb  Stump  Not Applicable
# 683686   191219         0          25   OnCurb  Stump  Not Applicable
# 683695   170888         0           5   OnCurb  Stump  Not Applicable
# 683697   177922         0          17   OnCurb  Stump  Not Applicable
# 683699   172660         0           4   OnCurb  Stump  Not Applicable
#
#              spc_latin         steward        sidewalk        problems  \
# ...

# %%
#find missing values 
tree_census_subset.isna().sum()
# Out:
# tree_id        0
# tree_dbh       0
# stump_diam     0
# curb_loc       0
# status         0
# health         1
# spc_latin      5
# steward        0
# sidewalk       1
# problems      49
# root_stone     0
# root_grate     0
# root_other     0
# root_other     0
# trunk_wire     0
# trnk_light     0
# trnk_other     0
# brch_light     0
# brch_shoe      0
# brch_other     0
# dtype: int64

# %%
tree_census_subset[tree_census_subset['health'].isna()]
# Out:
#        tree_id  tree_dbh  stump_diam curb_loc status health  \
# 32889   245041        16           0   OnCurb  Alive    NaN
#
#                     spc_latin steward sidewalk problems root_stone root_grate  \
# 32889  Fraxinus pennsylvanica    None   Damage     None         No         No
#
#       root_other root_other trunk_wire trnk_light trnk_other brch_light  \
# 32889         No         No         No         No         No         No
#
#       brch_shoe brch_other
# 32889        No         No

# %%
tree_census_subset['health'].value_counts()
# Out:
# Good              528850
# Fair               96504
# Not Applicable     31615
# Poor               26818
# Name: health, dtype: int64

# %%
tree_census_subset[tree_census_subset['sidewalk'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 346299   540677         7           0  OffsetFromCurb  Alive   Good
#
#                                  spc_latin steward sidewalk problems  \
# 346299  Gleditsia triacanthos var. inermis    None      NaN     None
#
#        root_stone root_grate root_other root_other trunk_wire trnk_light  \
# 346299         No         No         No         No         No         No
#
#        trnk_other brch_light brch_shoe brch_other
# 346299         No         No        No         No

# %%
tree_census_subset['steward'].value_counts()
# Out:
# None              487823
# 1or2              143557
# Not Applicable     31615
# 3or4               19183
# 4orMore             1610
# Name: steward, dtype: int64

# %%
tree_census_subset[tree_census_subset['problems'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 120289   332668        30           0  OffsetFromCurb  Alive   Fair
# 121488   332669        28           0  OffsetFromCurb  Alive   Fair
# 121685   332670        24           0  OffsetFromCurb  Alive   Fair
# 133470   332693        11           0  OffsetFromCurb  Alive   Good
# 133812   332692        15           0  OffsetFromCurb  Alive   Good
# 134820   332694        28           0  OffsetFromCurb  Alive   Good
# 144137   332947         3           0          OnCurb  Alive   Good
# 145324   332543         9           0          OnCurb  Alive   Good
# 145337   332541         8           0          OnCurb  Alive   Good
# 146314   332542         8           0          OnCurb  Alive   Good
# 146378   332950         3           0          OnCurb  Alive   Good
# 146430   332949         3           0          OnCurb  Alive   Good
# 146630   332948         3           0          OnCurb  Alive   Good
# ...

# %%
tree_census_subset['problems'].value_counts()
# Out:
# None                                                                          426280
# Stones                                                                         95673
# Not Applicable                                                                 31615
# BranchLights                                                                   29452
# Stones,BranchLights                                                            17808
#                                                                                ...
# Stones,RootOther,WiresRope,TrunkLights,TrunkOther,BranchLights,BranchOther         1
# Stones,MetalGrates,TrunkLights,TrunkOther                                          1
# MetalGrates,RootOther,TrunkLights,BranchLights                                     1
# WiresRope,TrunkOther,BranchLights,Sneakers                                         1
# MetalGrates,TrunkOther,Sneakers                                                    1
# Name: problems, Length: 233, dtype: int64

# %%
tree_census_subset[tree_census_subset['spc_latin'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 356613   562532         4           0   OnCurb  Alive   Good       NaN
# 427541   630814        11           0   OnCurb  Alive   Poor       NaN
# 431417   651014        40           0   OnCurb  Alive   Good       NaN
# 608632    47941         5           0   OnCurb  Alive   Good       NaN
# 656960   150745         3           0   OnCurb  Alive   Good       NaN
#
#        steward  sidewalk problems  ... root_other root_other trunk_wire  \
# 356613    1or2  NoDamage   Stones  ...         No         No         No
# 427541    None    Damage      NaN  ...         No         No         No
# 431417    None    Damage   Stones  ...         No         No         No
# 608632    1or2  NoDamage     None  ...         No         No         No
# 656960    1or2    Damage     None  ...         No         No         No
#
#        trnk_light trnk_other brch_light brch_shoe brch_other (9, NaN)  NaN
# ...

# %%
tree_census_subset['spc_latin'].value_counts()
# Out:
# Platanus x acerifolia                 87014
# Gleditsia triacanthos var. inermis    64264
# Pyrus calleryana                      58931
# Quercus palustris                     53185
# Acer platanoides                      34189
#                                       ...
# Pinus nigra                              37
# Pinus rigida                             33
# Maclura pomifera                         29
# Pinus sylvestris                         25
# Pinus virginiana                         10
# Name: spc_latin, Length: 133, dtype: int64

# %%
tree_census_subset[tree_census_subset['status']=='Alive']
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# ...

# %%
m =((tree_census_subset['spc_latin']=='NaN') | (tree_census_subset['spc_latin'] == 'NoObservation'))
m
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 683783    False
# 683784    False
# 683785    False
# 683786    False
# 683787    False
# Name: spc_latin, Length: 683788, dtype: bool

# %%
tree_census_subset[tree_census_subset['spc_latin'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37       211205         0          16          OnCurb  Stump    NaN       NaN
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 239      203597         0          15          OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683695   170888         0           5          OnCurb  Stump    NaN       NaN
# 683697   177922         0          17          OnCurb  Stump    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
# 683699   172660         0           4          OnCurb  Stump    NaN       NaN
#
# ...

# %%
tree_census_subset[tree_census_subset['sidewalk']==('NoDamage')]
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 5        190422        11           0   OnCurb  Alive   Good
# 6        190426        11           0   OnCurb  Alive   Good
# 7        208649         9           0   OnCurb  Alive   Good
# 8        209610         6           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683781   155348        20           0   OnCurb  Alive   Good
# 683782   184210         3           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk     problems  \
# 0                              Acer rubrum    None  NoDamage         None
# 5       Gleditsia triacanthos var. inermis    1or2  NoDamage         None
# ...

# %%
index_no = tree_census_subset.columns.get_loc('problems')
print(index_no)
# Out:
# 9

# %%
tree_census_subset[tree_census_subset['problems'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 120289   332668        30           0  OffsetFromCurb  Alive   Fair
# 121488   332669        28           0  OffsetFromCurb  Alive   Fair
# 121685   332670        24           0  OffsetFromCurb  Alive   Fair
# 133470   332693        11           0  OffsetFromCurb  Alive   Good
# 133812   332692        15           0  OffsetFromCurb  Alive   Good
# 134820   332694        28           0  OffsetFromCurb  Alive   Good
# 144137   332947         3           0          OnCurb  Alive   Good
# 145324   332543         9           0          OnCurb  Alive   Good
# 145337   332541         8           0          OnCurb  Alive   Good
# 146314   332542         8           0          OnCurb  Alive   Good
# 146378   332950         3           0          OnCurb  Alive   Good
# 146430   332949         3           0          OnCurb  Alive   Good
# 146630   332948         3           0          OnCurb  Alive   Good
# ...

# %%
tree_census_subset.isna().sum()
# Out:
# tree_id            0
# tree_dbh           0
# stump_diam         0
# curb_loc           0
# status             0
# health             1
# spc_latin          5
# steward            0
# sidewalk           1
# problems          49
# root_stone         0
# root_grate         0
# root_other         0
# root_other         0
# trunk_wire         0
# trnk_light         0
# trnk_other         0
# brch_light         0
# brch_shoe          0
# brch_other         0
# (9, NaN)           0
# NaN           683784
# dtype: int64

# %%
index_clm = tree_census_subset.columns.get_loc('problems')
print(index_clm)
# Out:
# 9

# %%
# problem column index at 9, replace NaN with None on all Alive status
problem_newvalue= tree_census_subset.at[9, 'NaN'] = 'None'
problem_newvalue
# Out:
# 'None'

# %%
# health column index at 5, replace NaN with Good on all Alive status
health_newvalue= tree_census_subset.at[5, 'NaN'] = 'Good'
health_newvalue
# Out:
# 'Good'

# %%
index_clm = tree_census_subset.columns.get_loc('health')
print(index_clm)
# Out:
# 5

# %%
# spc_latin colum index at 8, replace NaN with NoDamage on all Alive status
sidewalk_newvalue= tree_census_subset.at[8, 'NaN'] = 'NoDamage'
sidewalk_newvalue
# Out:
# 'NoDamage'

# %%
tree_census_subset[tree_census_subset['status']=='Alive']
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  ...  \
# 0                              Acer rubrum    None  NoDamage     None  ...
# 1                        Quercus palustris    None    Damage   Stones  ...
# ...

# %%
tree_census_subset[tree_census_subset['status']=='Stump']
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status          health  \
# 37       211205         0          16   OnCurb  Stump  Not Applicable
# 239      203597         0          15   OnCurb  Stump  Not Applicable
# 641      179766         0          30   OnCurb  Stump  Not Applicable
# 644      180619         0          10   OnCurb  Stump  Not Applicable
# 646      208828         0          15   OnCurb  Stump  Not Applicable
# ...         ...       ...         ...      ...    ...             ...
# 683348   152836         0          13   OnCurb  Stump  Not Applicable
# 683686   191219         0          25   OnCurb  Stump  Not Applicable
# 683695   170888         0           5   OnCurb  Stump  Not Applicable
# 683697   177922         0          17   OnCurb  Stump  Not Applicable
# 683699   172660         0           4   OnCurb  Stump  Not Applicable
#
#              spc_latin         steward        sidewalk        problems  ...  \
# ...

# %%
tree_census_subset[tree_census_subset['status']=='Dead']
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status          health  \
# 57       187807         0           0          OnCurb   Dead  Not Applicable
# 196      208322        10           0          OnCurb   Dead  Not Applicable
# 209      209058         6           0          OnCurb   Dead  Not Applicable
# 266      210544         6           0          OnCurb   Dead  Not Applicable
# 285      188609         9           0          OnCurb   Dead  Not Applicable
# ...         ...       ...         ...             ...    ...             ...
# 682816   184342        11           0          OnCurb   Dead  Not Applicable
# 682823   155430         2           0          OnCurb   Dead  Not Applicable
# 683346   156566        10           0          OnCurb   Dead  Not Applicable
# 683693   156162         3           0  OffsetFromCurb   Dead  Not Applicable
# 683698   193791         3           0          OnCurb   Dead  Not Applicable
#
# ...

# %%
tree_census_subset.isna().sum()
# Out:
# tree_id           0
# tree_dbh          0
# stump_diam        0
# curb_loc          0
# status            0
# health        31616
# spc_latin     31619
# steward       31615
# sidewalk      31616
# problems      31664
# root_stone        0
# root_grate        0
# root_other        0
# root_other        0
# trunk_wire        0
# trnk_light        0
# trnk_other        0
# brch_light        0
# brch_shoe         0
# brch_other        0
# dtype: int64

# %%
tree_census_subset[tree_census_subset['problems'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37       211205         0          16          OnCurb  Stump    NaN       NaN
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 239      203597         0          15          OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683695   170888         0           5          OnCurb  Stump    NaN       NaN
# 683697   177922         0          17          OnCurb  Stump    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
# 683699   172660         0           4          OnCurb  Stump    NaN       NaN
#
# ...

# %%
tree_census_subset = tree_census_subset[(tree_census_subset['tree_dbh']<=60) | (tree_census_subset['stump_diam']<= 60)]
tree_census_subset
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# ...

# %%
tree_census_subset_alive =tree_census_subset[tree_census_subset['status'] =="Alive"]

# %%
tree_census_subset_dead_or_Stump = tree_census_subset [(tree_census_subset['status']=='Stump') | (tree_census_subset['status'] =='Dead')]

# %%
tree_census_subset_alive.groupby('spc_latin').mean()
# Out:
#                          tree_id   tree_dbh  stump_diam
# spc_latin
# Acer               473760.032486  11.675424         0.0
# Acer buergerianum  395036.818182   8.090909         0.0
# Acer campestre     383840.281176   7.126275         0.0
# Acer ginnala       370801.015129   7.869204         0.0
# Acer griseum       347632.222727   3.509091         0.0
# ...                          ...        ...         ...
# Tsuga canadensis   268551.181818   5.193182         0.0
# Ulmus americana    308680.330533  11.953229         0.0
# Ulmus parvifolia   303458.441347   7.417587         0.0
# Ulmus pumila       318869.944828  11.475862         0.0
# Zelkova serrata    345718.008989   7.863559         0.0
#
# [132 rows x 3 columns]

# %%
tree_census_subset_alive.groupby('spc_latin').describe()
# Out:
#                    tree_id                                                    \
#                      count           mean            std      min        25%
# spc_latin
# Acer                7080.0  473760.032486  164789.472498    373.0  401640.00
# Acer buergerianum    110.0  395036.818182  179390.324434  60373.0  276777.50
# Acer campestre      2550.0  383840.281176  184855.325418    214.0  265393.25
# Acer ginnala        2049.0  370801.015129  184408.353698   1789.0  244993.00
# Acer griseum         220.0  347632.222727  181391.826314   8643.0  178650.75
# ...                    ...            ...            ...      ...        ...
# Tsuga canadensis      88.0  268551.181818  180119.744951  16887.0  145061.75
# Ulmus americana     7975.0  308680.330533  206913.335265    123.0  120745.50
# Ulmus parvifolia    5345.0  303458.441347  188585.417734    113.0  145469.00
# Ulmus pumila        1595.0  318869.944828  203420.294281    305.0  130366.50
# ...

# %%
tree_census_subset_alive.groupby('spc_latin')['tree_dbh'].describe()
# Out:
#                      count       mean       std  min  25%   50%   75%    max
# spc_latin
# Acer                7080.0  11.675424  6.577626  0.0  7.0  11.0  15.0   59.0
# Acer buergerianum    110.0   8.090909  4.544470  2.0  5.0   8.0  10.0   28.0
# Acer campestre      2550.0   7.126275  4.437674  0.0  4.0   6.0   9.0   64.0
# Acer ginnala        2049.0   7.869204  4.853365  0.0  4.0   7.0  10.0   40.0
# Acer griseum         220.0   3.509091  3.578846  1.0  2.0   2.0   3.0   30.0
# ...                    ...        ...       ...  ...  ...   ...   ...    ...
# Tsuga canadensis      88.0   5.193182  3.959153  0.0  2.0   3.5   7.0   21.0
# Ulmus americana     7975.0  11.953229  9.426278  0.0  4.0   9.0  17.0   65.0
# Ulmus parvifolia    5345.0   7.417587  5.867390  0.0  3.0   5.0  10.0  118.0
# Ulmus pumila        1595.0  11.475862  9.903164  1.0  4.0   9.0  17.0  149.0
# Zelkova serrata    29258.0   7.863559  5.297524  0.0  4.0   6.0  11.0  210.0
#
# [132 rows x 8 columns]

# %%
tree_census_subset_alive[tree_census_subset_alive['tree_dbh'] ==0]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 5312      38793         0           0          OnCurb  Alive   Good
# 30524    204988         0           0          OnCurb  Alive   Good
# 44772    241329         0           0  OffsetFromCurb  Alive   Good
# 47154    173248         0           0          OnCurb  Alive   Good
# 47484    204173         0           0          OnCurb  Alive   Poor
# ...         ...       ...         ...             ...    ...    ...
# 658977   162280         0           0          OnCurb  Alive   Poor
# 671073    17796         0           0          OnCurb  Alive   Fair
# 671971   120612         0           0          OnCurb  Alive   Good
# 672443   116239         0           0          OnCurb  Alive   Good
# 680530    51015         0           0          OnCurb  Alive   Good
#
#                    spc_latin steward  sidewalk problems root_stone root_grate  \
# ...

# %%
stats_alive = tree_census_subset_alive.groupby('spc_latin')['tree_dbh'].describe().reset_index()[['spc_latin', '25%','75%']]
stats_alive
# Out:
#              spc_latin  25%   75%
# 0                 Acer  7.0  15.0
# 1    Acer buergerianum  5.0  10.0
# 2       Acer campestre  4.0   9.0
# 3         Acer ginnala  4.0  10.0
# 4         Acer griseum  2.0   3.0
# ..                 ...  ...   ...
# 127   Tsuga canadensis  2.0   7.0
# 128    Ulmus americana  4.0  17.0
# 129   Ulmus parvifolia  3.0  10.0
# 130       Ulmus pumila  4.0  17.0
# 131    Zelkova serrata  4.0  11.0
#
# [132 rows x 3 columns]

# %%
tree_census_subset_alive.merge(stats_alive, on='spc_latin', how='left')
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 652168   155433        25           0   OnCurb  Alive   Good
# 652169   183795         7           0   OnCurb  Alive   Good
# 652170   166161        12           0   OnCurb  Alive   Good
# 652171   184028         9           0   OnCurb  Alive   Good
# 652172   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  ...  \
# 0                              Acer rubrum    None  NoDamage     None  ...
# 1                        Quercus palustris    None    Damage   Stones  ...
# ...
